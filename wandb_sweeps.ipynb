# %%
# %pip install -q wandb
# Out:
#      |████████████████████████████████| 1.7 MB 4.4 MB/s
#      |████████████████████████████████| 140 kB 56.5 MB/s
#      |████████████████████████████████| 97 kB 5.2 MB/s
#      |████████████████████████████████| 180 kB 48.3 MB/s
#      |████████████████████████████████| 63 kB 1.3 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done

# %%
# !wandb login
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# %load train_lib.py

def train():
    import numpy as np
    import tensorflow as tf
    import wandb
    config_defaults = {
        'layer1_size': 128,
        'layer1_activation': 'relu',
        'dropout_rate': 0.2,
        'optimizer': 'adam',
        'learning_rate': 0.01
    }
    wandb.init(project="sweep_practice", config=config_defaults, magic=True)

    config = wandb.config

    fashion_mnist = tf.keras.datasets.fashion_mnist
    (train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
    class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                   'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

    train_images.shape
    train_images = train_images / 255.0
    test_images = test_images / 255.0

    model = tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28, 28)),
        tf.keras.layers.Dense(config.layer1_size, activation=config.layer1_activation),
        tf.keras.layers.Dropout(config.dropout_rate),
        tf.keras.layers.Dense(10, activation=tf.nn.softmax)
    ])

    if config.optimizer=="rmsprop":
        opt = tf.keras.optimizers.RMSprop(learning_rate=config.learning_rate)
    else:
        opt = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)

    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    
    model.fit(train_images, train_labels, epochs=5,
                  validation_data=(test_images, test_labels))

# %%
sweep_config = {
    'method': 'grid',
    'parameters': {
        'layer1_size': {
            'values': [32, 64, 96, 128, 256]
        },
        'layer1_activation': {
            'values': ['relu', 'sigmoid']
        },
        'dropout_rate': {
            'values': [0.1, 0.2, 0.3, 0.4]
        },
        'optimizer': {
            'values': ['adam', 'rmsprop']
        },
        'learning_rate': {
            'values': [0.1, 0.01, 0.001]
        }
    }
}

# %%
import wandb
sweep_id = wandb.sweep(sweep_config, project="sweep_practice")
# Out:
# Create sweep with ID: xa8d8tcp
# Sweep URL: https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp

# %%
wandb.agent(sweep_id, function=train)
# Out:
# wandb: Agent Starting Run: u3m8twov with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/u3m8twov" target="_blank">fiery-sweep-1</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/5
#    1/1875 [..............................] - ETA: 19:47 - loss: 2.3468 - accuracy: 0.1250WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0038s). Check your callbacks.
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3381 - accuracy: 0.1016 - val_loss: 2.3104 - val_accuracy: 0.1000
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3160 - accuracy: 0.0985 - val_loss: 2.3165 - val_accuracy: 0.1000
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3157 - accuracy: 0.1007 - val_loss: 2.3196 - val_accuracy: 0.1000
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3158 - accuracy: 0.0989 - val_loss: 2.3185 - val_accuracy: 0.1000
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3156 - accuracy: 0.1001 - val_loss: 2.3106 - val_accuracy: 0.1000
# <br/>Waiting for W&B process to finish, PID 293... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.41MB of 0.41MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>█▁▆▂▅</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▆█▇▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.10008</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>2.31045</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>2.3156</td></tr><tr><td>val_accuracy</td><td>0.1</td></tr><tr><td>val_loss</td><td>2.31063</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fiery-sweep-1</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/u3m8twov" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/u3m8twov</a><br/>
# Find logs at: <code>./wandb/run-20211209_085110-u3m8twov/logs</code><br/>
# wandb: Agent Starting Run: 2sxgaub3 with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/2sxgaub3" target="_blank">generous-sweep-2</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 2.4106 - accuracy: 0.2336 - val_loss: 1.9889 - val_accuracy: 0.2213
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.0615 - accuracy: 0.2263 - val_loss: 1.9760 - val_accuracy: 0.2229
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.0358 - accuracy: 0.2383 - val_loss: 1.9453 - val_accuracy: 0.2325
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.0656 - accuracy: 0.2364 - val_loss: 1.9732 - val_accuracy: 0.2483
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.0627 - accuracy: 0.2519 - val_loss: 1.9689 - val_accuracy: 0.2529
# <br/>Waiting for W&B process to finish, PID 585... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.34MB of 0.35MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.98756066055…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▃▁▄▄█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▁▁▂▂</td></tr><tr><td>val_accuracy</td><td>▁▁▃▇█</td></tr><tr><td>val_loss</td><td>█▆▁▅▅</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.25193</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>1.94535</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>2.06274</td></tr><tr><td>val_accuracy</td><td>0.2529</td></tr><tr><td>val_loss</td><td>1.96891</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">generous-sweep-2</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/2sxgaub3" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/2sxgaub3</a><br/>
# Find logs at: <code>./wandb/run-20211209_085206-2sxgaub3/logs</code><br/>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: f7rbxr26 with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/f7rbxr26" target="_blank">comfy-sweep-3</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
#    1/1875 [..............................] - ETA: 11:04 - loss: 2.7116 - accuracy: 0.0938WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0018s vs `on_train_batch_end` time: 0.0038s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6130 - accuracy: 0.7772 - val_loss: 0.5243 - val_accuracy: 0.8160
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5308 - accuracy: 0.8100 - val_loss: 0.5119 - val_accuracy: 0.8152
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.5047 - accuracy: 0.8193 - val_loss: 0.4813 - val_accuracy: 0.8264
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4995 - accuracy: 0.8195 - val_loss: 0.4907 - val_accuracy: 0.8289
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4938 - accuracy: 0.8235 - val_loss: 0.4886 - val_accuracy: 0.8296
# <br/>Waiting for W&B process to finish, PID 868... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.44MB of 0.44MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▆▇▇█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▁▆██</td></tr><tr><td>val_loss</td><td>█▆▁▃▂</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.82353</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.48134</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.49385</td></tr><tr><td>val_accuracy</td><td>0.8296</td></tr><tr><td>val_loss</td><td>0.48858</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">comfy-sweep-3</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/f7rbxr26" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/f7rbxr26</a><br/>
# Find logs at: <code>./wandb/run-20211209_085252-f7rbxr26/logs</code><br/>
# wandb: Agent Starting Run: l7ppmx5g with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/l7ppmx5g" target="_blank">silvery-sweep-4</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6891 - accuracy: 0.7580 - val_loss: 0.5315 - val_accuracy: 0.8213
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6295 - accuracy: 0.7916 - val_loss: 0.6179 - val_accuracy: 0.8103
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6330 - accuracy: 0.7986 - val_loss: 0.5968 - val_accuracy: 0.8245
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6429 - accuracy: 0.8007 - val_loss: 0.7436 - val_accuracy: 0.8174
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6526 - accuracy: 0.7984 - val_loss: 0.7202 - val_accuracy: 0.8138
# <br/>Waiting for W&B process to finish, PID 1155... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.34MB of 0.35MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.98708293495…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▇███</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▁▁▃▄</td></tr><tr><td>val_accuracy</td><td>▆▁█▄▃</td></tr><tr><td>val_loss</td><td>▁▄▃█▇</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.79837</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>0.53149</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.65263</td></tr><tr><td>val_accuracy</td><td>0.8138</td></tr><tr><td>val_loss</td><td>0.72025</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">silvery-sweep-4</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/l7ppmx5g" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/l7ppmx5g</a><br/>
# Find logs at: <code>./wandb/run-20211209_085348-l7ppmx5g/logs</code><br/>
# wandb: Agent Starting Run: z9353h0r with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/z9353h0r" target="_blank">different-sweep-5</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6036 - accuracy: 0.7921 - val_loss: 0.4679 - val_accuracy: 0.8345
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4390 - accuracy: 0.8448 - val_loss: 0.4375 - val_accuracy: 0.8426
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4046 - accuracy: 0.8549 - val_loss: 0.4103 - val_accuracy: 0.8527
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3868 - accuracy: 0.8608 - val_loss: 0.3972 - val_accuracy: 0.8538
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3710 - accuracy: 0.8658 - val_loss: 0.3843 - val_accuracy: 0.8597
# <br/>Waiting for W&B process to finish, PID 1434... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.44MB of 0.44MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▆▇██</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▆▆█</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.8658</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.38433</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.37104</td></tr><tr><td>val_accuracy</td><td>0.8597</td></tr><tr><td>val_loss</td><td>0.38433</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">different-sweep-5</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/z9353h0r" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/z9353h0r</a><br/>
# Find logs at: <code>./wandb/run-20211209_085424-z9353h0r/logs</code><br/>
# wandb: Agent Starting Run: 09zpi19m with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 32
# wandb: 	learning_rate: 0.001
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/09zpi19m" target="_blank">peach-sweep-6</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
#    1/1875 [..............................] - ETA: 13:42 - loss: 2.3198 - accuracy: 0.1250WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0022s vs `on_train_batch_end` time: 0.0033s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5836 - accuracy: 0.7977 - val_loss: 0.4496 - val_accuracy: 0.8394
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4327 - accuracy: 0.8475 - val_loss: 0.4176 - val_accuracy: 0.8512
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4022 - accuracy: 0.8568 - val_loss: 0.4162 - val_accuracy: 0.8553
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3884 - accuracy: 0.8609 - val_loss: 0.4054 - val_accuracy: 0.8582
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3821 - accuracy: 0.8658 - val_loss: 0.4119 - val_accuracy: 0.8594
# <br/>Waiting for W&B process to finish, PID 1722... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.34MB of 0.35MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.98582161833…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▆▇▇█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▃▂▁▁</td></tr><tr><td>val_accuracy</td><td>▁▅▇██</td></tr><tr><td>val_loss</td><td>█▃▃▁▂</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.86585</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.40538</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.38205</td></tr><tr><td>val_accuracy</td><td>0.8594</td></tr><tr><td>val_loss</td><td>0.4119</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">peach-sweep-6</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/09zpi19m" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/09zpi19m</a><br/>
# Find logs at: <code>./wandb/run-20211209_085516-09zpi19m/logs</code><br/>
# wandb: Agent Starting Run: f0m7faaf with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/f0m7faaf" target="_blank">sunny-sweep-7</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
#    1/1875 [..............................] - ETA: 12:19 - loss: 2.3141 - accuracy: 0.1250WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0024s vs `on_train_batch_end` time: 0.0030s). Check your callbacks.
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.2118 - accuracy: 0.1910 - val_loss: 2.0503 - val_accuracy: 0.1914
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.1204 - accuracy: 0.1746 - val_loss: 2.3126 - val_accuracy: 0.1000
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3160 - accuracy: 0.0982 - val_loss: 2.3072 - val_accuracy: 0.1000
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3152 - accuracy: 0.0990 - val_loss: 2.3120 - val_accuracy: 0.1000
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3155 - accuracy: 0.1023 - val_loss: 2.3177 - val_accuracy: 0.1000
# <br/>Waiting for W&B process to finish, PID 2013... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.73MB of 0.73MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.99484476790…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>█▇▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>▄▁███</td></tr><tr><td>val_accuracy</td><td>█▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁████</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.10227</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>2.05035</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>2.31552</td></tr><tr><td>val_accuracy</td><td>0.1</td></tr><tr><td>val_loss</td><td>2.31773</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">sunny-sweep-7</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/f0m7faaf" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/f0m7faaf</a><br/>
# Find logs at: <code>./wandb/run-20211209_085552-f0m7faaf/logs</code><br/>
# wandb: Agent Starting Run: zss8ow1d with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.1
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/zss8ow1d" target="_blank">usual-sweep-8</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
#    1/1875 [..............................] - ETA: 15:25 - loss: 2.1469 - accuracy: 0.1875WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0027s vs `on_train_batch_end` time: 0.0041s). Check your callbacks.
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.7759 - accuracy: 0.2204 - val_loss: 1.7206 - val_accuracy: 0.3450
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9812 - accuracy: 0.3233 - val_loss: 1.7774 - val_accuracy: 0.3729
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9233 - accuracy: 0.3494 - val_loss: 1.7023 - val_accuracy: 0.3761
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.8541 - accuracy: 0.3489 - val_loss: 1.8199 - val_accuracy: 0.3670
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9219 - accuracy: 0.3568 - val_loss: 1.7288 - val_accuracy: 0.3712
# <br/>Waiting for W&B process to finish, PID 2297... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.54MB of 0.54MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▆███</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▂▂▁▂</td></tr><tr><td>val_accuracy</td><td>▁▇█▆▇</td></tr><tr><td>val_loss</td><td>▂▅▁█▃</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.35675</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>1.70228</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>1.92194</td></tr><tr><td>val_accuracy</td><td>0.3712</td></tr><tr><td>val_loss</td><td>1.72876</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">usual-sweep-8</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/zss8ow1d" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/zss8ow1d</a><br/>
# Find logs at: <code>./wandb/run-20211209_085633-zss8ow1d/logs</code><br/>
# wandb: Agent Starting Run: 7duycad2 with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: adam
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/7duycad2" target="_blank">classic-sweep-9</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
#    1/1875 [..............................] - ETA: 11:01 - loss: 2.5320 - accuracy: 0.0938WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0021s vs `on_train_batch_end` time: 0.0039s). Check your callbacks.
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5994 - accuracy: 0.7829 - val_loss: 0.4917 - val_accuracy: 0.8260
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5181 - accuracy: 0.8126 - val_loss: 0.5340 - val_accuracy: 0.8175
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5029 - accuracy: 0.8180 - val_loss: 0.4754 - val_accuracy: 0.8414
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4920 - accuracy: 0.8234 - val_loss: 0.5258 - val_accuracy: 0.8105
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4724 - accuracy: 0.8293 - val_loss: 0.4618 - val_accuracy: 0.8376
# <br/>Waiting for W&B process to finish, PID 2578... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.73MB of 0.73MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▅▆▇█</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>loss</td><td>█▄▃▂▁</td></tr><tr><td>val_accuracy</td><td>▅▃█▁▇</td></tr><tr><td>val_loss</td><td>▄█▂▇▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.82927</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.46179</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>loss</td><td>0.47237</td></tr><tr><td>val_accuracy</td><td>0.8376</td></tr><tr><td>val_loss</td><td>0.46179</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# <br/>Synced <strong style="color:#cdcd00">classic-sweep-9</strong>: <a href="https://wandb.ai/hongmin/sweep_practice/runs/7duycad2" target="_blank">https://wandb.ai/hongmin/sweep_practice/runs/7duycad2</a><br/>
# Find logs at: <code>./wandb/run-20211209_085730-7duycad2/logs</code><br/>
# wandb: Agent Starting Run: 9hpkz13j with config:
# wandb: 	dropout_rate: 0.1
# wandb: 	layer1_activation: relu
# wandb: 	layer1_size: 64
# wandb: 	learning_rate: 0.01
# wandb: 	optimizer: rmsprop
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
#                     Syncing run <strong><a href="https://wandb.ai/hongmin/sweep_practice/runs/9hpkz13j" target="_blank">solar-sweep-10</a></strong> to <a href="https://wandb.ai/hongmin/sweep_practice" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>
# Sweep page: <a href="https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp" target="_blank">https://wandb.ai/hongmin/sweep_practice/sweeps/xa8d8tcp</a><br/>
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.6923 - accuracy: 0.7715 - val_loss: 0.5647 - val_accuracy: 0.8208
# Epoch 2/5
#  448/1875 [======>.......................] - ETA: 6s - loss: 0.6023 - accuracy: 0.8055
# wandb: Ctrl + C detected. Stopping sweep.

# %%
with open('train.py', 'w') as f:
    f.write(
        """
import numpy as np
import tensorflow as tf
import wandb
config_defaults = {
    'layer1_size': 128,
    'layer1_activation': 'relu',
    'dropout_rate': 0.2,
    'optimizer': 'adam',
    'learning_rate': 0.01
}
wandb.init(project="sweep_practice", config=config_defaults, magic=True)

config = wandb.config

fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images.shape
train_images = train_images / 255.0
test_images = test_images / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(config.layer1_size, activation=config.layer1_activation),
    tf.keras.layers.Dropout(config.dropout_rate),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

if config.optimizer=="rmsprop":
    opt = tf.keras.optimizers.RMSprop(learning_rate=config.learning_rate)
else:
    opt = tf.keras.optimizers.Adam(learning_rate=config.learning_rate)

model.compile(optimizer=opt,
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5,
                validation_data=(test_images, test_labels))
        """
    )

# %%
# !head train.py
# Out:
# import numpy as np
# import tensorflow as tf
# import wandb
# config_defaults = {
#     'layer1_size': 128,
#     'layer1_activation': 'relu',
#     'dropout_rate': 0.2,
#     'optimizer': 'adam',
#     'learning_rate': 0.01

# %%
# create sweep in sweep page

# !wandb agent hongmin/sweep_practice/1rva3a6g
# Out:
# wandb: Starting wandb agent 🕵️
# 2021-12-09 09:00:22,712 - wandb.wandb_agent - INFO - Running runs: []
# 2021-12-09 09:00:22,931 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:00:22,931 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.0836060725731034
# 	layer1_activation: sigmoid
# 	layer1_size: 47
# 	learning_rate: 0.1845270018069297
# 	optimizer: rmsprop
# 2021-12-09 09:00:22,933 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.0836060725731034 --layer1_activation=sigmoid --layer1_size=47 --learning_rate=0.1845270018069297 --optimizer=rmsprop
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:00:27,944 - wandb.wandb_agent - INFO - Running runs: ['cfk9kvc0']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run ancient-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/cfk9kvc0
# wandb: Run data is saved locally in /content/wandb/run-20211209_090026-cfk9kvc0
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:00:31.653593: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
#    1/1875 [..............................] - ETA: 20:00 - loss: 2.4781 - accuracy: 0.1562WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0023s vs `on_train_batch_end` time: 0.0026s). Check your callbacks.
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.8839 - accuracy: 0.5327 - val_loss: 1.1027 - val_accuracy: 0.6659
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.5957 - accuracy: 0.6234 - val_loss: 1.3655 - val_accuracy: 0.6146
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.4821 - accuracy: 0.6441 - val_loss: 1.2985 - val_accuracy: 0.7161
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.3801 - accuracy: 0.6583 - val_loss: 1.4707 - val_accuracy: 0.6844
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.3734 - accuracy: 0.6738 - val_loss: 1.1079 - val_accuracy: 0.6978
#
# wandb: Waiting for W&B process to finish, PID 3021... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy ▁▆▇▇█
# wandb:          epoch ▁▃▅▆█
# wandb:           loss █▄▂▁▁
# wandb:   val_accuracy ▅▁█▆▇
# wandb:       val_loss ▁▆▅█▁
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.67378
# wandb:      best_epoch 0
# wandb:   best_val_loss 1.10267
# wandb:           epoch 4
# wandb:            loss 1.37336
# wandb:    val_accuracy 0.6978
# wandb:        val_loss 1.10793
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced ancient-sweep-4: https://wandb.ai/hongmin/sweep_practice/runs/cfk9kvc0
# wandb: Find logs at: ./wandb/run-20211209_090026-cfk9kvc0/logs/debug.log
# wandb:
# 2021-12-09 09:01:08,749 - wandb.wandb_agent - INFO - Cleaning up finished run: cfk9kvc0
# 2021-12-09 09:01:09,173 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:01:09,173 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.1924518578386477
# 	layer1_activation: relu
# 	layer1_size: 117
# 	learning_rate: 0.10146116278026662
# 	optimizer: adam
# 2021-12-09 09:01:09,176 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.1924518578386477 --layer1_activation=relu --layer1_size=117 --learning_rate=0.10146116278026662 --optimizer=adam
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:01:14,188 - wandb.wandb_agent - INFO - Running runs: ['mdz1nya2']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run daily-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/mdz1nya2
# wandb: Run data is saved locally in /content/wandb/run-20211209_090112-mdz1nya2
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:01:17.551835: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.4291 - accuracy: 0.1256 - val_loss: 2.3126 - val_accuracy: 0.1000
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3166 - accuracy: 0.0998 - val_loss: 2.3126 - val_accuracy: 0.1000
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3154 - accuracy: 0.0984 - val_loss: 2.3120 - val_accuracy: 0.1000
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3153 - accuracy: 0.0992 - val_loss: 2.3147 - val_accuracy: 0.1000
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3159 - accuracy: 0.0980 - val_loss: 2.3159 - val_accuracy: 0.1000
#
# wandb: Waiting for W&B process to finish, PID 3323... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy █▁▁▁▁
# wandb:          epoch ▁▃▅▆█
# wandb:           loss █▁▁▁▁
# wandb:   val_accuracy ▁▁▁▁▁
# wandb:       val_loss ▂▂▁▆█
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.09802
# wandb:      best_epoch 2
# wandb:   best_val_loss 2.31195
# wandb:           epoch 4
# wandb:            loss 2.31587
# wandb:    val_accuracy 0.1
# wandb:        val_loss 2.31593
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced daily-sweep-5: https://wandb.ai/hongmin/sweep_practice/runs/mdz1nya2
# wandb: Find logs at: ./wandb/run-20211209_090112-mdz1nya2/logs/debug.log
# wandb:
# 2021-12-09 09:02:10,107 - wandb.wandb_agent - INFO - Cleaning up finished run: mdz1nya2
# 2021-12-09 09:02:10,386 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:02:10,387 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.1598418157380846
# 	layer1_activation: sigmoid
# 	layer1_size: 126
# 	learning_rate: 0.10878051966925945
# 	optimizer: rmsprop
# 2021-12-09 09:02:10,389 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.1598418157380846 --layer1_activation=sigmoid --layer1_size=126 --learning_rate=0.10878051966925945 --optimizer=rmsprop
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:02:15,397 - wandb.wandb_agent - INFO - Running runs: ['6teih72r']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run azure-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/6teih72r
# wandb: Run data is saved locally in /content/wandb/run-20211209_090214-6teih72r
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:02:19.349053: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 1.6742 - accuracy: 0.6001 - val_loss: 1.1117 - val_accuracy: 0.6865
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.6403 - accuracy: 0.6636 - val_loss: 1.3819 - val_accuracy: 0.7152
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.5863 - accuracy: 0.6841 - val_loss: 1.5306 - val_accuracy: 0.6643
# Epoch 4/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.5099 - accuracy: 0.7036 - val_loss: 1.5341 - val_accuracy: 0.6370
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.5302 - accuracy: 0.7121 - val_loss: 1.4084 - val_accuracy: 0.7476
#
# wandb: Waiting for W&B process to finish, PID 3628... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy ▁▅▆▇█
# wandb:          epoch ▁▃▅▆█
# wandb:           loss █▇▄▁▂
# wandb:   val_accuracy ▄▆▃▁█
# wandb:       val_loss ▁▅██▆
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.71208
# wandb:      best_epoch 0
# wandb:   best_val_loss 1.11173
# wandb:           epoch 4
# wandb:            loss 1.53018
# wandb:    val_accuracy 0.7476
# wandb:        val_loss 1.4084
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced azure-sweep-6: https://wandb.ai/hongmin/sweep_practice/runs/6teih72r
# wandb: Find logs at: ./wandb/run-20211209_090214-6teih72r/logs/debug.log
# wandb:
# 2021-12-09 09:03:11,452 - wandb.wandb_agent - INFO - Cleaning up finished run: 6teih72r
# 2021-12-09 09:03:11,769 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:03:11,769 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.16864885217159853
# 	layer1_activation: sigmoid
# 	layer1_size: 84
# 	learning_rate: 0.17250566772735984
# 	optimizer: rmsprop
# 2021-12-09 09:03:11,771 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.16864885217159853 --layer1_activation=sigmoid --layer1_size=84 --learning_rate=0.17250566772735984 --optimizer=rmsprop
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:03:16,783 - wandb.wandb_agent - INFO - Running runs: ['c22u9its']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run cerulean-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/c22u9its
# wandb: Run data is saved locally in /content/wandb/run-20211209_090315-c22u9its
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:03:20.225664: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.6682 - accuracy: 0.5462 - val_loss: 1.0428 - val_accuracy: 0.6746
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.5480 - accuracy: 0.6183 - val_loss: 1.0112 - val_accuracy: 0.6795
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4625 - accuracy: 0.6527 - val_loss: 1.0138 - val_accuracy: 0.7273
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4296 - accuracy: 0.6641 - val_loss: 1.4168 - val_accuracy: 0.6993
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4256 - accuracy: 0.6734 - val_loss: 1.0734 - val_accuracy: 0.6622
#
# wandb: Waiting for W&B process to finish, PID 3934... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy ▁▅▇▇█
# wandb:          epoch ▁▃▅▆█
# wandb:           loss █▅▂▁▁
# wandb:   val_accuracy ▂▃█▅▁
# wandb:       val_loss ▂▁▁█▂
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.67338
# wandb:      best_epoch 1
# wandb:   best_val_loss 1.01117
# wandb:           epoch 4
# wandb:            loss 1.42559
# wandb:    val_accuracy 0.6622
# wandb:        val_loss 1.07343
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced cerulean-sweep-7: https://wandb.ai/hongmin/sweep_practice/runs/c22u9its
# wandb: Find logs at: ./wandb/run-20211209_090315-c22u9its/logs/debug.log
# wandb:
# 2021-12-09 09:04:12,661 - wandb.wandb_agent - INFO - Cleaning up finished run: c22u9its
# 2021-12-09 09:04:12,906 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:04:12,906 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.18937771434391415
# 	layer1_activation: relu
# 	layer1_size: 110
# 	learning_rate: 0.05806199520379388
# 	optimizer: adam
# 2021-12-09 09:04:12,908 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.18937771434391415 --layer1_activation=relu --layer1_size=110 --learning_rate=0.05806199520379388 --optimizer=adam
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:04:17,920 - wandb.wandb_agent - INFO - Running runs: ['2ajorngl']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run solar-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/2ajorngl
# wandb: Run data is saved locally in /content/wandb/run-20211209_090416-2ajorngl
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:04:21.357029: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.6937 - accuracy: 0.3532 - val_loss: 1.6301 - val_accuracy: 0.3353
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9142 - accuracy: 0.2555 - val_loss: 1.7472 - val_accuracy: 0.2867
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9792 - accuracy: 0.2329 - val_loss: 1.8784 - val_accuracy: 0.2593
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.9569 - accuracy: 0.2396 - val_loss: 1.8199 - val_accuracy: 0.2843
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9924 - accuracy: 0.2274 - val_loss: 2.0967 - val_accuracy: 0.1770
#
# wandb: Waiting for W&B process to finish, PID 4236... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy █▃▁▂▁
# wandb:          epoch ▁▃▅▆█
# wandb:           loss ▁▆█▇█
# wandb:   val_accuracy █▆▅▆▁
# wandb:       val_loss ▁▃▅▄█
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.22737
# wandb:      best_epoch 0
# wandb:   best_val_loss 1.63015
# wandb:           epoch 4
# wandb:            loss 1.99241
# wandb:    val_accuracy 0.177
# wandb:        val_loss 2.09667
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced solar-sweep-8: https://wandb.ai/hongmin/sweep_practice/runs/2ajorngl
# wandb: Find logs at: ./wandb/run-20211209_090416-2ajorngl/logs/debug.log
# wandb:
# 2021-12-09 09:05:13,891 - wandb.wandb_agent - INFO - Cleaning up finished run: 2ajorngl
# 2021-12-09 09:05:14,143 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:05:14,143 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.19708871622377927
# 	layer1_activation: relu
# 	layer1_size: 118
# 	learning_rate: 0.12486628240397342
# 	optimizer: adam
# 2021-12-09 09:05:14,145 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.19708871622377927 --layer1_activation=relu --layer1_size=118 --learning_rate=0.12486628240397342 --optimizer=adam
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:05:19,154 - wandb.wandb_agent - INFO - Running runs: ['ki2lf113']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run usual-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/ki2lf113
# wandb: Run data is saved locally in /content/wandb/run-20211209_090518-ki2lf113
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:05:22.886766: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.5060 - accuracy: 0.1103 - val_loss: 2.3152 - val_accuracy: 0.1000
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3371 - accuracy: 0.1010 - val_loss: 2.3256 - val_accuracy: 0.1000
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3182 - accuracy: 0.0998 - val_loss: 2.3210 - val_accuracy: 0.1000
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3187 - accuracy: 0.0990 - val_loss: 2.3112 - val_accuracy: 0.1000
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3186 - accuracy: 0.0988 - val_loss: 2.3145 - val_accuracy: 0.1000
#
# wandb: Waiting for W&B process to finish, PID 4538... (success).
# wandb:
# wandb: Run history:
# wandb:       accuracy █▂▂▁▁
# wandb:          epoch ▁▃▅▆█
# wandb:           loss █▂▁▁▁
# wandb:   val_accuracy ▁▁▁▁▁
# wandb:       val_loss ▃█▆▁▃
# wandb:
# wandb: Run summary:
# wandb:        accuracy 0.09878
# wandb:      best_epoch 3
# wandb:   best_val_loss 2.31124
# wandb:           epoch 4
# wandb:            loss 2.3186
# wandb:    val_accuracy 0.1
# wandb:        val_loss 2.31452
# wandb:
# wandb: Synced 5 W&B file(s), 181 media file(s), 0 artifact file(s) and 3 other file(s)
# wandb: Synced usual-sweep-9: https://wandb.ai/hongmin/sweep_practice/runs/ki2lf113
# wandb: Find logs at: ./wandb/run-20211209_090518-ki2lf113/logs/debug.log
# wandb:
# 2021-12-09 09:06:15,247 - wandb.wandb_agent - INFO - Cleaning up finished run: ki2lf113
# 2021-12-09 09:06:15,500 - wandb.wandb_agent - INFO - Agent received command: run
# 2021-12-09 09:06:15,500 - wandb.wandb_agent - INFO - Agent starting run with config:
# 	dropout_rate: 0.17118033597890908
# 	layer1_activation: relu
# 	layer1_size: 126
# 	learning_rate: 0.11971429147870773
# 	optimizer: adam
# 2021-12-09 09:06:15,502 - wandb.wandb_agent - INFO - About to run command: /usr/bin/env python train.py --dropout_rate=0.17118033597890908 --layer1_activation=relu --layer1_size=126 --learning_rate=0.11971429147870773 --optimizer=adam
# wandb: Currently logged in as: hongmin (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:06:20,514 - wandb.wandb_agent - INFO - Running runs: ['77qndivc']
# wandb: Tracking run with wandb version 0.12.7
# wandb: Syncing run noble-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/hongmin/sweep_practice
# wandb: 🧹 View sweep at https://wandb.ai/hongmin/sweep_practice/sweeps/1rva3a6g
# wandb: 🚀 View run at https://wandb.ai/hongmin/sweep_practice/runs/77qndivc
# wandb: Run data is saved locally in /content/wandb/run-20211209_090619-77qndivc
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: WARNING Ignored wandb.init() arg project when running a sweep
# 2021-12-09 09:06:23.875320: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.4422 - accuracy: 0.1329 - val_loss: 2.3100 - val_accuracy: 0.1000
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.3177 - accuracy: 0.1007 - val_loss: 2.3303 - val_accuracy: 0.1000
# Epoch 3/5
# 1723/1875 [==========================>...] - ETA: 0s - loss: 2.3191 - accuracy: 0.1008wandb: Terminating and syncing runs. Press ctrl-c to kill.
# /usr/lib/python3.7/multiprocessing/semaphore_tracker.py:144: UserWarning: semaphore_tracker: There appear to be 6 leaked semaphores to clean up at shutdown
#   len(cache))
